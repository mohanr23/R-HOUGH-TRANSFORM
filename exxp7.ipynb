# %% [markdown]
# ## Exp-7-Record-HOUGH TRANSFORM
# *Name : MOHAN R*
#
# *Reg.No : 212224230168*

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("Hero.png",0)
img_c=cv2.imread("Hero.png",1)
img_c=cv2.cvtColor(img_c,cv2.COLOR_BGR2RGB)
gray=cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
gray = cv2.GaussianBlur(gray,(3,3),0)
plt.figure(figsize=(13,13))
plt.subplot(1,2,1)
plt.imshow(img_c)
plt.title("Original Image")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(gray)
plt.title("Gray Image")
plt.axis("off")
plt.show()

# %%
canny=cv2.Canny(gray,100,140)
plt.imshow(canny)
plt.title("Canny Edge Detector")
plt.axis("off")
plt.show()

# %%
lines=cv2.HoughLinesP(canny,1,np.pi/180,threshold=80,minLineLength=50,maxLineGap=250)

# %%
for line in lines:
    x1,y1,x2,y2=line[0]
    cv2.line(img_c,(x1,y1),(x2,y2),(255,10,0),3)

# %%
plt.imshow(img_c)
plt.title("Result Image")
plt.axis("off")
plt.show()
